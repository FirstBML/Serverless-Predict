# %% [markdown]
# - Click the link below to access full note and instructions for the model
#
#
# [NoteBook's Link](https://github.com/DataTalksClub/machine-learning-zoomcamp/tree/master/09-serverless/workshop)
